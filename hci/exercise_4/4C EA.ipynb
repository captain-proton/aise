# %% [markdown]
# Bei Kombination der besten Eltern zum Referenzknoten kann der Fall auftreten, dass ein Kind entsteht, was dem gesuchten entspricht. Mutationen sind hier zwingend erforderlich, da sich die Vielfalt der Population ohne sie gegenseitig auslöscht.

# %%
# %pip install ansicolors
# DO NOT EDIT THIS CELL
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# DO NOT EDIT THIS CELL

from colors import color
import os
import random
import time
import sys

# %%
# DO NOT EDIT THIS CELL
# DO NOT EDIT THIS CELL
# DO NOT EDIT THIS CELL

class ColorBinVector:
    def __init__(self):
        """Constructor of a new ColorVector. The ColorVector is initialized with random RGB values."""
        r = random.randint(0, 255)
        g = random.randint(0, 255)
        b = random.randint(0, 255)
        self.set_color(r, g, b)
        self.num = get_id()

    def __repr__(self):
        return color('#' + self.get_hex(), '', '#' + self.get_hex())

    def set_color(self, r, g, b) -> None:
        """Explicitly sets the RGB-values of the ColorVector."""
        r = int(r)
        g = int(g)
        b = int(b)
        self.hexcolor = '{:02x}{:02x}{:02x}'.format(r, g, b)       # hex representation e.g. '4c7da0'
        self.bincolor = "{0:024b}".format(int(self.hexcolor, 16))  # 3 bytes (r, g, b)

    def get_bin(self) -> str:
        """Returns a binary representation of the ColorVector."""
        return self.bincolor

    def set_bin(self, binstr: str) -> None:
        """Sets the binary representation of the ColorVector from a binary string."""
        r = int(binstr[:8], 2)
        g = int(binstr[8:16], 2)
        b = int(binstr[16:], 2)
        self.set_color(r, g, b)

    def get_hex(self) -> str:
        """Returns a hexadecimal representation of the ColorVector."""
        return self.hexcolor

    def get_num(self) -> str:
        return str(self.num)
    
    def print(self) -> None:
        try: 
            print('ColorBinVec '+str(self.num)+': ' + str(self) + ' (-> ' + self.get_bin() + ') ' + 
                  ', f = ' + str(fitness_function(self, TARGET_COLOR_BIN_VECTOR)))
        except NameError as ne:
            print('ColorBinVec '+str(self.num)+': ' + str(self) + ' (-> ' + self.get_bin() + ') ')

# DO NOT EDIT THIS CELL
# DO NOT EDIT THIS CELL
# DO NOT EDIT THIS CELL

_id=0
def get_id():
    """Returns a unique, incremented ID."""
    global _id
    ret_id = _id
    _id += 1
    return ret_id

# DO NOT EDIT THIS CELL
# DO NOT EDIT THIS CELL
# DO NOT EDIT THIS CELL

# This is a randomly chosen target vector
TARGET_COLOR_BIN_VECTOR = ColorBinVector()

# %%
print("This is the target vector: ", end='')
TARGET_COLOR_BIN_VECTOR.print()

# This is a list in Python
population = []
# Out:
# This is the target vector: ColorBinVec 0: #bbe1b1 (-> 101110111110000110110001)

# %%
# TODO Task 4C.1:
# Generate 10 objects from ColorBinVector and append them to the list `population`

# TODO insert some code here
population += [ColorBinVector() for _ in range(10)]

# %%
if len(population) == 0:
    print("NOTICE: You did not add any vector to `population` :-(")
else: 
    for p in population:
        p.print()
# Out:
# ColorBinVec 1: #d6aeb1 (-> 110101101010111010110001)
# ColorBinVec 2: #dee247 (-> 110111101110001001000111)
# ColorBinVec 3: #5fdb7a (-> 010111111101101101111010)
# ColorBinVec 4: #4835eb (-> 010010000011010111101011)
# ColorBinVec 5: #7b520f (-> 011110110101001000001111)
# ColorBinVec 6: #056794 (-> 000001010110011110010100)
# ColorBinVec 7: #c53617 (-> 110001010011011000010111)
# ColorBinVec 8: #93eb47 (-> 100100111110101101000111)
# ColorBinVec 9: #edcbe8 (-> 111011011100101111101000)
# ColorBinVec 10: #823da9 (-> 100000100011110110101001)

# %%
# Task 4C.2:
# Implement the Hamming Distance as a fitness function that is calculated over `vector1` and `vector2`
# A Hamming Distance of zero means, that there is no difference between `vector1` and `vector2`

def fitness_function(vector1: ColorBinVector, vector2: ColorBinVector) -> int:
    # TODO: Implement and return the hamming distance between s1 and s2
    b1 = vector1.get_bin()
    b2 = vector2.get_bin()
    #print(b1)
    #print(b2)
    #for t in zip(b1, b2):
    #    print(t)
        
    return sum([1 if t[0] != t[1] else 0 for t in zip(vector1.get_bin(), vector2.get_bin())])

fitness_function(population[0], population[1])
# Out:
# 10

# %%
# Task 4C.3:
# Implement a mutation of vector1
# The function should take `vector1` as an argument and return a new ColorBinVector that has 
# (for example) two of its bits flipped at a random position within the vector.
# Hint: use random.randint(0, len(vector1)) twice but check for inequal results
# Hint: Use get_bin() and set_bin() of ColorBinVector

def mutation(vector1: ColorBinVector, flip=2) -> ColorBinVector:
    binary = list(vector1.get_bin())
    #print(''.join(binary))
    
    flip_indexes = random.sample(range(len(binary)), flip)
    #print(flip_indexes)
    for index in flip_indexes:
        binary[index] = "0" if binary[index] == "1" else "1"
    vector1.set_bin(''.join(binary))
    return vector1

v = ColorBinVector()
print(mutation(v).get_bin())
# Out:
# 010100010100111000101110

# %%
# Task 4C.4:
# Implement a function that creates a crossover between two vectors
# This function should combine some part of vector1 with some other part of vector2.

def crossover(vector1: ColorBinVector, vector2: ColorBinVector) -> ColorBinVector:
    b1 = vector1.get_bin()
    b2 = vector2.get_bin()
    
    binary = ''.join([b1[0:8], b2[8:16], b1[16:24]])
    
    v = ColorBinVector()
    v.set_bin(binary)
    return v

v = ColorBinVector()
w = ColorBinVector()
print(v.get_bin())
print(crossover(v, w).get_bin())
# Out:
# 111100001100010100101111
# 111100000110101100101111

# %%
class SurvivalOfTheNFittest():
    
    def __init__(self, beeings: list,
                 mutation_chance=50,
                 flip_count=lambda: 2):
        super().__init__()
        self.beeings = beeings
        self.mutation_chance = 50
        self.flip_count = flip_count
        
    def mutate(self):
        
        for i in range(len(self.beeings)):
            
            if random.randint(1, 100) <= self.mutation_chance:
                
                beeing = mutation(self.beeings[i], self.flip_count())
                self.beeings[i] = beeing
    
    def evolve(self) -> list:
        
        children = []
        children += [crossover(self.beeings[0], beeing) for beeing in self.beeings[1:6]]
        children += [crossover(self.beeings[1], beeing) for beeing in self.beeings[2:7]]
        self.beeings = children
        
        if self.mutation_chance > 0:
            self.mutate()
        
        return self.beeings

# %%
class Centipede(SurvivalOfTheNFittest):
    
    def __init__(self, beeings: list,
                 mutation_chance=50,
                 flip_count=lambda: 2):
        super().__init__(beeings, mutation_chance, flip_count)
        
    def evolve(self) -> list:
                
        # prepend the second beeing to produce a sibling
        self.beeings.insert(0, self.beeings[1])
        
        # pair each beeing with the next inside the population
        self.beeings = [crossover(self.beeings[i], self.beeings[i + 1]) 
                        for i in range(len(self.beeings) - 1)]
        
        if self.mutation_chance > 0:
            self.mutate()
        
        return self.beeings

# %%
class NoEvolution(SurvivalOfTheNFittest):
    def __init__(self, beeings: list,
                 flip_count=lambda: 2):
        super().__init__(beeings, mutation_chance=0, flip_count=flip_count)

# %%
# Task 4C.5: 
# Implement an algorithm that creates a generation of children from its parents.
# Perform crossovers and rarely mutations.
# In the end, all elements of population should be changed except.
# Hint: the list `population` is sorted by fitness from high to low.
# Important: the size of the population needs to be kept constant.

def create_child_generation(parent_population: list) -> list:
    # TODO transform the parental population into a child generation and return it
    
    strategy = SurvivalOfTheNFittest(parent_population)
    #strategy = Centipede(parent_population)
    #strategy = NoEvolution(parent_population)
    
    children = strategy.evolve()
    return children

max_generations = 200
verbose_output = True

# %%
# DO NOT EDIT THIS CELL
# DO NOT EDIT THIS CELL
# DO NOT EDIT THIS CELL

# This is the generation population loop
for i in range (0, max_generations):
    population = sorted(population, key=lambda v: fitness_function(v, TARGET_COLOR_BIN_VECTOR))
    
    if(TARGET_COLOR_BIN_VECTOR.get_bin() == population[0].get_bin() 
       and not fitness_function(population[0], TARGET_COLOR_BIN_VECTOR) == 42):
        print("SUCCESS!")
        print("A vector has fully matched TARGET_COLOR_BIN_VECTOR after " + str(i) + " generations.")
    
    population_size = len(population)
    
    population = create_child_generation(population)
    
    population_children_size = len(population)
    
    if(population_size != population_children_size):
        raise Exception("Error: Violating size constraint - you have more children than parents. \
        population_size=" + str(population_size) + ", population_children_size=" + str(population_children_size))
        
    if verbose_output:
        print("------------------------------------------------------------------------------")
        
    TARGET_COLOR_BIN_VECTOR.print()
    print("Generation " + str(i) + ": ", end='')
    print(population)
    print()
    if verbose_output:
        for p in population:
            p.print()
        print("------------------------------------------------------------------------------")
        print()
        print()
    
# DO NOT EDIT THIS CELL
# DO NOT EDIT THIS CELL
# DO NOT EDIT THIS CELL
# Out:
# ------------------------------------------------------------------------------
# ColorBinVec 0: #bbe1b1 (-> 101110111110000110110001) , f = 0
# Generation 0: [#d6ebb1, #d6cbb1, #d63db1, #d6e2b1, #d627f1, #93cb47, #931c47, #d3e24f, #d16747, #91db07]
#
# ColorBinVec 15: #d6ebb1 (-> 110101101110101110110001) , f = 7
# ColorBinVec 16: #d6cbb1 (-> 110101101100101110110001) , f = 8
# ColorBinVec 17: #d63db1 (-> 110101100011110110110001) , f = 10
# ColorBinVec 18: #d6e2b1 (-> 110101101110001010110001) , f = 7
# ColorBinVec 19: #d627f1 (-> 110101100010011111110001) , f = 10
# ColorBinVec 20: #93cb47 (-> 100100111100101101000111) , f = 11
# ColorBinVec 21: #931c47 (-> 100100110001110001000111) , f = 15
# ColorBinVec 22: #d3e24f (-> 110100111110001001001111) , f = 12
# ColorBinVec 23: #d16747 (-> 110100010110011101000111) , f = 13
# ColorBinVec 24: #91db07 (-> 100100011101101100000111) , f = 12
# ------------------------------------------------------------------------------
#
#
# ...
